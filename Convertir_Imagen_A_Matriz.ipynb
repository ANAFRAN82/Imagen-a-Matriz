# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Cargar la imagen usando Pillow
image_path = '/home/anita/Programcion_Logica/m.png'
img = Image.open(image_path)

img_array = np.array(img)

plt.imshow(img_array) 
plt.title('Imagen en color')
plt.show()

print(img_array)
print(f"Dimensiones de la matriz: {img_array.shape}")
# Out:
# [[[ 12  14  62]
#   [ 12  14  62]
#   [ 12  14  62]
#   ...
#   [  5   5  15]
#   [  5   5  15]
#   [  5   5  15]]
#
#  [[ 12  14  62]
#   [ 12  14  62]
#   [ 12  14  62]
#   ...
#   [  5   5  15]
#   [  5   5  15]
#   [  5   5  15]]
#
#  [[ 12  14  62]
#   [ 12  14  62]
#   [ 12  14  62]
#   ...
#   [  5   5  15]
#   [  5   5  15]
#   [  5   5  15]]
#
#  ...
#
#  [[ 83 140 253]
#   [ 83 140 253]
#   [ 83 140 253]
#   ...
#   [ 60  76 198]
#   [ 59  75 197]
#   [ 59  75 197]]
#
#  [[ 83 140 253]
#   [ 83 140 253]
#   [ 83 140 253]
#   ...
#   [ 60  76 198]
#   [ 59  75 197]
#   [ 59  75 197]]
#
#  [[ 83 140 253]
#   [ 83 140 253]
#   [ 83 140 253]
#   ...
#   [ 60  76 198]
#   [ 59  75 197]
#   [ 59  75 197]]]
# Dimensiones de la matriz: (981, 736, 3)
